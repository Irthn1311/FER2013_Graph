# %% [markdown]
# # PGM M0 M42-M44
# Fixed sparse nonlinear arm seeds 42,43,44. Predictions only.

# %%
from pathlib import Path
import shutil, subprocess, sys
REPO='https://github.com/Irthn1311/FER2013_Graph.git'; SHA='4cac8941635a7aadb2bd0dac646a0be406ee08f6'
P=Path('/kaggle/working/FER2013_Graph_M0_WRAPPER')
if P.exists(): shutil.rmtree(P)
subprocess.run(['git','clone',REPO,str(P)],check=True); subprocess.run(['git','-C',str(P),'checkout','--detach',SHA],check=True)
subprocess.run([sys.executable,str(P/'notebooks/m0-fit-entry.py'),'--family','M','--seeds','42','43','44','--account','trngthngcnhi'],check=True)
