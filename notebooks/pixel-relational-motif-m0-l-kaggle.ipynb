# %% [markdown]
# # PGM M0 L
# Fixed strengthened linear arm. Predictions only.

# %%
from pathlib import Path
import shutil, subprocess, sys
REPO='https://github.com/Irthn1311/FER2013_Graph.git'; SHA='0b030632db66ba7e8fe47c1240f1a27e412b9ef4'
P=Path('/kaggle/working/FER2013_Graph_M0_WRAPPER')
if P.exists(): shutil.rmtree(P)
subprocess.run(['git','clone',REPO,str(P)],check=True); subprocess.run(['git','-C',str(P),'checkout','--detach',SHA],check=True)
subprocess.run([sys.executable,str(P/'notebooks/m0-fit-entry.py'),'--family','L','--account','nuyntai'],check=True)
