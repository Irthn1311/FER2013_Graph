# %% [markdown]
# # PGM M0 M45-M46
# Fixed sparse nonlinear arm seeds 45,46. Predictions only.

# %%
from pathlib import Path
import shutil, subprocess, sys
REPO='https://github.com/Irthn1311/FER2013_Graph.git'; SHA='4b0349be2600c2797fc8fc61a8a6a48ffbabdb37'
P=Path('/kaggle/working/FER2013_Graph_M0_WRAPPER')
if P.exists(): shutil.rmtree(P)
subprocess.run(['git','clone',REPO,str(P)],check=True); subprocess.run(['git','-C',str(P),'checkout','--detach',SHA],check=True)
subprocess.run([sys.executable,str(P/'notebooks/m0-fit-entry.py'),'--family','M','--seeds','45','46','--account','thanhhhgng'],check=True)
