# %% [markdown]
# # PGM M0 G42
# Fixed graph arm seed 42. Predictions only.

# %%
from pathlib import Path
import shutil, subprocess, sys
REPO='https://github.com/Irthn1311/FER2013_Graph.git'; SHA='9f13126b7ee4975012b62f221b2d828d5b53c2bd'
P=Path('/kaggle/working/FER2013_Graph_M0_WRAPPER')
if P.exists(): shutil.rmtree(P)
subprocess.run(['git','clone',REPO,str(P)],check=True); subprocess.run(['git','-C',str(P),'checkout','--detach',SHA],check=True)
subprocess.run([sys.executable,str(P/'notebooks/m0-fit-entry.py'),'--family','G','--seeds','42','--account','trngthngcnhi'],check=True)
